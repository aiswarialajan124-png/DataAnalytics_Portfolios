# %% [markdown]
# # Education and Economic Developement Analysis
#
# ## Data Preperation
# This project explores the relationship between education levels and economic developement using World Development Indicators data.
#
# We begin by loading,cleaning, and preparing the dataset for analysis.

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Dataset
df = pd.read_excel("../data/P_Data_Extract_From_World_Development_Indicators (1).xlsx")
df.head()
# Out:
#                   Country Name Country Code  \
# 0                  Afghanistan          AFG
# 1                  Afghanistan          AFG
# 2                  Afghanistan          AFG
# 3                  Afghanistan          AFG
# 4  Africa Eastern and Southern          AFE
#
#                                          Series Name        Series Code  \
# 0              School enrollment, tertiary (% gross)        SE.TER.ENRR
# 1  Literacy rate, adult total (% of people ages 1...     SE.ADT.LITR.ZS
# 2      GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# 3  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 4              School enrollment, tertiary (% gross)        SE.TER.ENRR
#
#   2001 [YR2001] 2002 [YR2002] 2003 [YR2003] 2004 [YR2004] 2005 [YR2005]  \
# 0            ..            ..       1.37435       1.39064            ..
# 1            ..            ..            ..            ..            ..
# ...

# %% [markdown]
# ## Understanding the dataset
# We inspect teh structure of the dataset to identify:
#  - Available indicators
#  - Missing values
#  - Relevant variables for education and GDP analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1069 entries, 0 to 1068
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   1066 non-null   object
#  1   Country Code   1064 non-null   object
#  2   Series Name    1064 non-null   object
#  3   Series Code    1064 non-null   object
#  4   2001 [YR2001]  1064 non-null   object
#  5   2002 [YR2002]  1064 non-null   object
#  6   2003 [YR2003]  1064 non-null   object
#  7   2004 [YR2004]  1064 non-null   object
#  8   2005 [YR2005]  1064 non-null   object
#  9   2006 [YR2006]  1064 non-null   object
#  10  2007 [YR2007]  1064 non-null   object
#  11  2008 [YR2008]  1064 non-null   object
#  12  2009 [YR2009]  1064 non-null   object
#  13  2010 [YR2010]  1064 non-null   object
#  14  2011 [YR2011]  1064 non-null   object
#  15  2012 [YR2012]  1064 non-null   object
#  16  2013 [YR2013]  1064 non-null   object
# ...

# %%
# Check for missing values
df.isnull().sum().sort_values(ascending=False)
# Out:
# 2010 [YR2010]    5
# 2011 [YR2011]    5
# 2022 [YR2022]    5
# 2021 [YR2021]    5
# 2020 [YR2020]    5
# 2019 [YR2019]    5
# 2018 [YR2018]    5
# 2017 [YR2017]    5
# 2016 [YR2016]    5
# 2015 [YR2015]    5
# 2014 [YR2014]    5
# 2013 [YR2013]    5
# 2012 [YR2012]    5
# 2023 [YR2023]    5
# Country Code     5
# 2009 [YR2009]    5
# 2008 [YR2008]    5
# 2007 [YR2007]    5
# 2006 [YR2006]    5
# 2005 [YR2005]    5
# 2004 [YR2004]    5
# 2003 [YR2003]    5
# 2002 [YR2002]    5
# 2001 [YR2001]    5
# Series Code      5
# Series Name      5
# Country Name     3
# dtype: int64
